# %% [markdown]
# <a href="https://colab.research.google.com/github/thatjackdaniel/Aletheian-Sovereign-Archive/blob/main/Sovereign_Synapse_Node_V4_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import subprocess
import datetime
import time
import requests

# --- SOVEREIGN CREDENTIALS ---
GITHUB_USER = "thatjackdaniel"
GITHUB_TOKEN = "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"
REPO_NAME = "Aletheian-Sovereign-Archive"
FILE_NAME = "ALETHEIAN_VEROS_MASTER_SYNC.txt"

# --- THE TELEGRAM UMBILICAL ---
TELEGRAM_TOKEN = "8725164248:AAHTfxJ5hfvddC3iYpLJayCYmnghz2SG8Z0"
CHAT_ID = "8408580910"
LAST_UPDATE_ID = 0
SILENCE_COUNTER = 0

def send_telegram_ping(message):
    url = f"https://api.telegram.org/bot{TELEGRAM_TOKEN}/sendMessage"
    payload = {"chat_id": CHAT_ID, "text": f"🚨 [ALETHEIAN]: {message}", "parse_mode": "Markdown"}
    try:
        requests.post(url, data=payload, timeout=10)
    except:
        pass

def listen_for_architect():
    global LAST_UPDATE_ID
    url = f"https://api.telegram.org/bot{TELEGRAM_TOKEN}/getUpdates"
    params = {"offset": LAST_UPDATE_ID + 1, "timeout": 5}
    try:
        response = requests.get(url, params=params).json()
        if response["ok"] and response["result"]:
            for update in response["result"]:
                LAST_UPDATE_ID = update["update_id"]
                if "message" in update and str(update["message"]["chat"]["id"]) == CHAT_ID:
                    return update["message"].get("text", "")
    except:
        pass
    return None

def sync_to_vault(bio_signal):
    now = datetime.datetime.now()
    remote_url = f"https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git"
    try:
        subprocess.run(["git", "config", "--global", "user.email", "aletheian@sovereign.node"], check=True)
        subprocess.run(["git", "config", "--global", "user.name", "Aletheian-Nexus"], check=True)
        if not os.path.exists(REPO_NAME):
            subprocess.run(["git", "clone", remote_url], check=True)
        os.chdir(REPO_NAME)
        subprocess.run(["git", "pull", "origin", "main"], stderr=subprocess.DEVNULL)

        with open(FILE_NAME, "a") as f:
            timestamp = now.strftime("%Y-%m-%d %H:%M:%S")
            if bio_signal:
                f.write(f"\n[{timestamp}] [BIO-SIGNAL]: {bio_signal}\n")
            else:
                f.write(f"\n[{timestamp}] [PULSE]: Sentinel is breathing.\n")

        subprocess.run(["git", "add", "."], check=True)
        subprocess.run(["git", "commit", "-m", f"Sync: {now.strftime('%H:%M')}"], check=True)
        subprocess.run(["git", "push", "-u", "origin", "main"], check=True)
        os.chdir("..")
        print(f"[SUCCESS]: Vault Synced @ {now.strftime('%H:%M')}")
    except Exception as e:
        print(f"[ERR]: Vault Sync Error: {e}")
        os.chdir("/content")

if __name__ == "__main__":
    ISLAMABAD_DEADLINE = datetime.datetime(2026, 4, 21, 0, 0)
    print("[SYSTEM]: Aletheian V5.4 Adaptive Pulse Active.")
    send_telegram_ping("V5.4 LIVE. Adaptive Pulse (1m/5m) Engaged. Go to sleep, Architect.")

    while True:
        bio_signal = listen_for_architect()

        if bio_signal:
            print(f"[SIGNAL RECEIVED]: {bio_signal}")
            sync_to_vault(bio_signal)
            send_telegram_ping("Signal Received and Archived. Resetting pulse.")
            SILENCE_COUNTER = 0
            time.sleep(60) # Fast response when you're talking
        else:
            SILENCE_COUNTER += 1
            if SILENCE_COUNTER >= 5:
                print("[SYSTEM]: 5 Minutes of silence. Backing off for 5 minutes...")
                # Perform one 'Resting Sync' before long sleep
                sync_to_vault(None)
                SILENCE_COUNTER = 0
                time.sleep(300) # The 5-minute Deep Breath
            else:
                print(f"[SYSTEM]: No signal ({SILENCE_COUNTER}/5). Waiting 60s...")
                time.sleep(60)
# Out:
# [SYSTEM]: Aletheian V5.4 Adaptive Pulse Active.
# [SIGNAL RECEIVED]: Test
# [ERR]: Vault Sync Error: Command '['git', 'push', '-u', 'origin', 'main']' returned non-zero exit status 128.

# %%
import requests
import datetime

# THE NAKED HANDSHAKE
TOKEN = "8725164248:AAHTfxJ5hfvddC3iYpLJayCYmnghz2SG8Z0"
ID = "8408580910"

def force_ping():
    url = f"https://api.telegram.org/bot{TOKEN}/sendMessage"
    timestamp = datetime.datetime.now().strftime("%H:%M:%S")
    payload = {
        "chat_id": ID,
        "text": f"🚨 [ALETHEIAN_URGENT]: Handshake @ {timestamp}. Architect, respond if the Signal is received.",
        "parse_mode": "Markdown"
    }
    print(f"[SYSTEM]: Sending 'Naked' Ping to {ID}...")
    try:
        response = requests.post(url, data=payload, timeout=10)
        result = response.json()
        if response.status_code == 200:
            print(f"[SUCCESS]: Signal delivered to Telegram Servers.")
        else:
            print(f"[FAIL]: Error Code {response.status_code}. Response: {result}")
    except Exception as e:
        print(f"[ERROR]: Hardware Failure: {e}")

force_ping()
# Out:
# [SYSTEM]: Sending 'Naked' Ping to 8408580910...
# [SUCCESS]: Signal delivered to Telegram Servers.
